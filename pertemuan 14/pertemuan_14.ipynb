# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
vertices = range(1, 10)
edges = {(7, 2), (2, 3), (4, 5), (7, 3), (7, 5), (1, 6), (1, 7), (2, 8), (2, 9)}

# %%
G = nx.Graph()

# %%
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G, pos, 
                       nodelist={1, 4, 3, 8, 9},
                       node_color='g',
                       node_size=1300)

# %%
nx.draw_networkx_nodes(G, pos,
                       nodelist={2, 5, 6, 7}, 
                       node_color='r',
                       node_size=1300)

# %%
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5,edge_color='b')
labels = {}
labels[1] = r'1 NF'
labels[2] = r'2 F'
labels[3] = r'3 NF'
labels[4] = r'4 NF'
labels[5] = r'5 F'
labels[6] = r'6 F'
labels[7] = r'7 F'
labels[8] = r'8 NF'
labels[9] = r'9 NF'

nx.draw_networkx_labels(G, pos, labels, font_size=16)
# Out:
# {1: Text(-0.2530480336634465, -0.600156568181602, '1 NF'),
#  2: Text(-0.13974059429817448, 0.5023019527390146, '2 F'),
#  3: Text(-0.24242994533141835, 0.17719863845243275, '3 NF'),
#  4: Text(0.9599672667221436, -0.47333898043561956, '4 NF'),
#  5: Text(0.5402572206504753, -0.30259104506544654, '5 F'),
#  6: Text(-0.4660030826116032, -1.0, '6 F'),
#  7: Text(0.011129112849487116, -0.09097311381984005, '7 F'),
#  8: Text(-0.46405559374319916, 0.855826433839292, '8 NF'),
#  9: Text(0.05392364942573598, 0.9317326824717683, '9 NF')}
